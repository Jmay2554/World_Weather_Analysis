# %%
# Add dependencies
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import numpy as np
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# add the city coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Begin the api call

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        # City Description
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
     
  
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mayo
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | srednekolymsk
# Processing Record 5 of Set 1 | thinadhoo
# Processing Record 6 of Set 1 | la asuncion
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | wajir
# Processing Record 9 of Set 1 | mount isa
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | oussouye
# Processing Record 13 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | benguela
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | avera
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | saint-augustin
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | dudinka
# Processing Record 26 of Set 1 | khandyga
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | dunedin
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | amahai
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | zwedru
# Processing Record 40 of Set 1 | beckley
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | wagar
# Processing Record 44 of Set 1 | campos altos
# Processing Record 45 of Set 1 | acopiara
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | zapolyarnyy
# Processing Record 48 of Set 1 | centerville
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | ljungby
# Processing Record 2 of Set 2 | poum
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | pravia
# Processing Record 5 of Set 2 | ayan
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | elk grove
# Processing Record 8 of Set 2 | primorsko
# Processing Record 9 of Set 2 | parrita
# Processing Record 10 of Set 2 | portland
# Processing Record 11 of Set 2 | nara
# Processing Record 12 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 2 | gawler
# Processing Record 14 of Set 2 | skagen
# Processing Record 15 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 2 | newport
# Processing Record 17 of Set 2 | morehead
# Processing Record 18 of Set 2 | carutapera
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | thunder bay
# Processing Record 21 of Set 2 | oksfjord
# Processing Record 22 of Set 2 | medicine hat
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | iberia
# Processing Record 29 of Set 2 | gat
# Processing Record 30 of Set 2 | praia
# Processing Record 31 of Set 2 | hovd
# Processing Record 32 of Set 2 | bukama
# Processing Record 33 of Set 2 | wuwei
# Processing Record 34 of Set 2 | aykhal
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | chalmette
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | lakes entrance
# Processing Record 40 of Set 2 | van
# Processing Record 41 of Set 2 | tezu
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | batemans bay
# Processing Record 44 of Set 2 | itarema
# Processing Record 45 of Set 2 | hami
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | natal
# Processing Record 49 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 2 | sao filipe
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | muisne
# Processing Record 4 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 3 | port victoria
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | acapulco
# Processing Record 9 of Set 3 | padang
# Processing Record 10 of Set 3 | aswan
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | skibbereen
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | mackenzie
# Processing Record 17 of Set 3 | alta floresta
# Processing Record 18 of Set 3 | taoudenni
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | yeletskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | jingdezhen
# Processing Record 25 of Set 3 | husavik
# Processing Record 26 of Set 3 | atikokan
# Processing Record 27 of Set 3 | eyl
# Processing Record 28 of Set 3 | mayor pablo lagerenza
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | constitucion
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | darnah
# Processing Record 33 of Set 3 | hervey bay
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | sibolga
# Processing Record 37 of Set 3 | paveh
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | bacolod
# Processing Record 40 of Set 3 | tire
# Processing Record 41 of Set 3 | grindavik
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | pisco
# Processing Record 45 of Set 3 | kerema
# Processing Record 46 of Set 3 | lipany
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | kaeo
# Processing Record 49 of Set 3 | odweyne
# Processing Record 50 of Set 3 | pemberton
# Processing Record 1 of Set 4 | mayahi
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | micheweni
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | gombong
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | baruun-urt
# Processing Record 11 of Set 4 | broome
# Processing Record 12 of Set 4 | evensk
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | asekeyevo
# Processing Record 15 of Set 4 | punta arenas
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | bahia blanca
# Processing Record 18 of Set 4 | svetlaya
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | kutum
# Processing Record 21 of Set 4 | ban nahin
# Processing Record 22 of Set 4 | yerbogachen
# Processing Record 23 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 24 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | calama
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | hokitika
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 4 | querfurt
# Processing Record 32 of Set 4 | nacozari
# Processing Record 33 of Set 4 | mahina
# Processing Record 34 of Set 4 | paso de los toros
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | assiniboia
# Processing Record 38 of Set 4 | urulga
# City not found. Skipping...
# Processing Record 39 of Set 4 | chenzhou
# Processing Record 40 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 4 | east london
# Processing Record 42 of Set 4 | mahon
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 46 of Set 4 | teya
# Processing Record 47 of Set 4 | bereda
# Processing Record 48 of Set 4 | kulhudhuffushi
# Processing Record 49 of Set 4 | warrnambool
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | atasu
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | muros
# Processing Record 5 of Set 5 | vila do maio
# Processing Record 6 of Set 5 | saint-louis
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | prince albert
# Processing Record 9 of Set 5 | marsh harbour
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 5 | san rafael
# Processing Record 13 of Set 5 | porto empedocle
# Processing Record 14 of Set 5 | clearwater
# Processing Record 15 of Set 5 | kathmandu
# Processing Record 16 of Set 5 | acarau
# Processing Record 17 of Set 5 | ilhabela
# Processing Record 18 of Set 5 | port moresby
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | salinopolis
# Processing Record 21 of Set 5 | komsomolskiy
# Processing Record 22 of Set 5 | svetlogorsk
# Processing Record 23 of Set 5 | mineros
# Processing Record 24 of Set 5 | paamiut
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | altay
# Processing Record 28 of Set 5 | taganrog
# Processing Record 29 of Set 5 | qaanaaq
# Processing Record 30 of Set 5 | kaitangata
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | nieuw amsterdam
# Processing Record 33 of Set 5 | bambanglipuro
# Processing Record 34 of Set 5 | havelock
# Processing Record 35 of Set 5 | gonen
# Processing Record 36 of Set 5 | georgetown
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | kennett
# Processing Record 39 of Set 5 | invermere
# Processing Record 40 of Set 5 | barbastro
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | macamic
# Processing Record 44 of Set 5 | pevek
# Processing Record 45 of Set 5 | paita
# Processing Record 46 of Set 5 | ambilobe
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | viedma
# Processing Record 49 of Set 5 | chancay
# Processing Record 50 of Set 5 | jinsha
# Processing Record 1 of Set 6 | mudhol
# Processing Record 2 of Set 6 | kidal
# Processing Record 3 of Set 6 | manthani
# Processing Record 4 of Set 6 | dubreka
# Processing Record 5 of Set 6 | temerloh
# Processing Record 6 of Set 6 | cartagena
# Processing Record 7 of Set 6 | fukue
# Processing Record 8 of Set 6 | upernavik
# Processing Record 9 of Set 6 | yankton
# Processing Record 10 of Set 6 | kismayo
# Processing Record 11 of Set 6 | bilibino
# Processing Record 12 of Set 6 | la palma
# Processing Record 13 of Set 6 | hatillo
# Processing Record 14 of Set 6 | sagada
# Processing Record 15 of Set 6 | ixtapa
# Processing Record 16 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 6 | alcaniz
# Processing Record 18 of Set 6 | spisske podhradie
# Processing Record 19 of Set 6 | vanderhoof
# Processing Record 20 of Set 6 | dongsheng
# Processing Record 21 of Set 6 | maningrida
# Processing Record 22 of Set 6 | visby
# Processing Record 23 of Set 6 | meadow lake
# Processing Record 24 of Set 6 | oriximina
# Processing Record 25 of Set 6 | chapais
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | vostok
# Processing Record 28 of Set 6 | goderich
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | auki
# Processing Record 31 of Set 6 | vila franca do campo
# Processing Record 32 of Set 6 | plouzane
# Processing Record 33 of Set 6 | hinjilikatu
# Processing Record 34 of Set 6 | arraial do cabo
# Processing Record 35 of Set 6 | kouango
# Processing Record 36 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | qabis
# City not found. Skipping...
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | namatanai
# Processing Record 42 of Set 6 | nhulunbuy
# Processing Record 43 of Set 6 | samarai
# Processing Record 44 of Set 6 | xichang
# Processing Record 45 of Set 6 | karwar
# Processing Record 46 of Set 6 | santiago de chuco
# Processing Record 47 of Set 6 | pandan
# Processing Record 48 of Set 6 | college
# Processing Record 49 of Set 6 | westport
# Processing Record 50 of Set 6 | luganville
# Processing Record 1 of Set 7 | paragominas
# Processing Record 2 of Set 7 | nurota
# Processing Record 3 of Set 7 | belgaum
# Processing Record 4 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 5 of Set 7 | owerri
# Processing Record 6 of Set 7 | kharp
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | beruwala
# Processing Record 9 of Set 7 | tsumeb
# Processing Record 10 of Set 7 | castro
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | saint-joseph
# Processing Record 14 of Set 7 | bialogard
# Processing Record 15 of Set 7 | yulara
# Processing Record 16 of Set 7 | abu samrah
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | sao francisco de assis
# Processing Record 19 of Set 7 | mar del plata
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | burnie
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | vestmannaeyjar
# Processing Record 24 of Set 7 | collie
# Processing Record 25 of Set 7 | moose factory
# Processing Record 26 of Set 7 | porto novo
# Processing Record 27 of Set 7 | santana do livramento
# Processing Record 28 of Set 7 | severnyy
# Processing Record 29 of Set 7 | hofn
# Processing Record 30 of Set 7 | nokaneng
# Processing Record 31 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 7 | kamenka
# Processing Record 33 of Set 7 | puerto colombia
# Processing Record 34 of Set 7 | matata
# Processing Record 35 of Set 7 | fallon
# Processing Record 36 of Set 7 | alegrete
# Processing Record 37 of Set 7 | heihe
# Processing Record 38 of Set 7 | mukdahan
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | asfi
# Processing Record 41 of Set 7 | ongandjera
# Processing Record 42 of Set 7 | puerto escondido
# Processing Record 43 of Set 7 | emba
# Processing Record 44 of Set 7 | ponta do sol
# Processing Record 45 of Set 7 | alamosa
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 7 | skjervoy
# Processing Record 1 of Set 8 | blairmore
# Processing Record 2 of Set 8 | zhanaozen
# Processing Record 3 of Set 8 | ojinaga
# Processing Record 4 of Set 8 | bonavista
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | nouadhibou
# Processing Record 8 of Set 8 | christchurch
# Processing Record 9 of Set 8 | omarska
# Processing Record 10 of Set 8 | vestmanna
# Processing Record 11 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 8 | isangel
# Processing Record 13 of Set 8 | gaoua
# Processing Record 14 of Set 8 | orshanka
# Processing Record 15 of Set 8 | faanui
# Processing Record 16 of Set 8 | manuk mangkaw
# Processing Record 17 of Set 8 | tazovskiy
# Processing Record 18 of Set 8 | ola
# Processing Record 19 of Set 8 | rundu
# Processing Record 20 of Set 8 | volnovakha
# Processing Record 21 of Set 8 | brigantine
# Processing Record 22 of Set 8 | sebina
# Processing Record 23 of Set 8 | teknaf
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | hithadhoo
# Processing Record 26 of Set 8 | asau
# Processing Record 27 of Set 8 | saldanha
# Processing Record 28 of Set 8 | belmonte
# Processing Record 29 of Set 8 | perth
# Processing Record 30 of Set 8 | yakima
# Processing Record 31 of Set 8 | nyurba
# Processing Record 32 of Set 8 | ormara
# Processing Record 33 of Set 8 | paredon
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | maceio
# Processing Record 36 of Set 8 | quatre cocos
# Processing Record 37 of Set 8 | henties bay
# Processing Record 38 of Set 8 | oskaloosa
# Processing Record 39 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 8 | tzucacab
# Processing Record 41 of Set 8 | sur
# Processing Record 42 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 43 of Set 8 | neiafu
# Processing Record 44 of Set 8 | langenhagen
# Processing Record 45 of Set 8 | yining
# Processing Record 46 of Set 8 | niceville
# Processing Record 47 of Set 8 | orbetello
# Processing Record 48 of Set 8 | ovruch
# Processing Record 49 of Set 8 | tombouctou
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | airai
# Processing Record 2 of Set 9 | leningradskiy
# Processing Record 3 of Set 9 | peddapalli
# Processing Record 4 of Set 9 | anchorage
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | lithakia
# Processing Record 7 of Set 9 | ishigaki
# Processing Record 8 of Set 9 | keti bandar
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | barguzin
# Processing Record 11 of Set 9 | obo
# Processing Record 12 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 9 | cabedelo
# Processing Record 14 of Set 9 | tuskegee
# Processing Record 15 of Set 9 | klaksvik
# Processing Record 16 of Set 9 | tungor
# Processing Record 17 of Set 9 | bronnoysund
# Processing Record 18 of Set 9 | zhigansk
# Processing Record 19 of Set 9 | envira
# Processing Record 20 of Set 9 | padre bernardo
# Processing Record 21 of Set 9 | haicheng
# Processing Record 22 of Set 9 | morgan city
# Processing Record 23 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 9 | beloha
# Processing Record 25 of Set 9 | los llanos de aridane
# Processing Record 26 of Set 9 | nishihara
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | kangaatsiaq
# Processing Record 29 of Set 9 | maniitsoq
# Processing Record 30 of Set 9 | verkh-usugli
# Processing Record 31 of Set 9 | ruy barbosa
# Processing Record 32 of Set 9 | lebedyn
# Processing Record 33 of Set 9 | pakxan
# Processing Record 34 of Set 9 | fayaoue
# Processing Record 35 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 9 | kang
# Processing Record 37 of Set 9 | winnemucca
# Processing Record 38 of Set 9 | muroto
# Processing Record 39 of Set 9 | kyra
# Processing Record 40 of Set 9 | ipanema
# Processing Record 41 of Set 9 | vernon
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | houston
# Processing Record 44 of Set 9 | qaqortoq
# Processing Record 45 of Set 9 | shimoda
# Processing Record 46 of Set 9 | the valley
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | santo tomas
# Processing Record 49 of Set 9 | naranjal
# Processing Record 50 of Set 9 | stornoway
# Processing Record 1 of Set 10 | isla mujeres
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | aden
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 10 | cherskiy
# Processing Record 7 of Set 10 | nizhniy baskunchak
# Processing Record 8 of Set 10 | olafsvik
# Processing Record 9 of Set 10 | ganzhou
# Processing Record 10 of Set 10 | malanje
# Processing Record 11 of Set 10 | aginskoye
# Processing Record 12 of Set 10 | port augusta
# Processing Record 13 of Set 10 | miri
# Processing Record 14 of Set 10 | jining
# Processing Record 15 of Set 10 | arlit
# Processing Record 16 of Set 10 | belaya gora
# Processing Record 17 of Set 10 | bahir dar
# Processing Record 18 of Set 10 | turukhansk
# Processing Record 19 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 10 | kedrovyy
# Processing Record 21 of Set 10 | touros
# Processing Record 22 of Set 10 | bowen
# Processing Record 23 of Set 10 | palora
# Processing Record 24 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 10 | ayabe
# Processing Record 26 of Set 10 | puerto penasco
# Processing Record 27 of Set 10 | maltahohe
# Processing Record 28 of Set 10 | moree
# Processing Record 29 of Set 10 | berliste
# Processing Record 30 of Set 10 | dabat
# Processing Record 31 of Set 10 | mayumba
# Processing Record 32 of Set 10 | celestun
# Processing Record 33 of Set 10 | hammerfest
# Processing Record 34 of Set 10 | simplicio mendes
# Processing Record 35 of Set 10 | spirit river
# Processing Record 36 of Set 10 | chifeng
# Processing Record 37 of Set 10 | yeppoon
# Processing Record 38 of Set 10 | coahuayana
# Processing Record 39 of Set 10 | birin
# Processing Record 40 of Set 10 | pokhara
# Processing Record 41 of Set 10 | ponta delgada
# Processing Record 42 of Set 10 | narsaq
# Processing Record 43 of Set 10 | cabatuan
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | boende
# Processing Record 47 of Set 10 | pyaozerskiy
# Processing Record 48 of Set 10 | kishi
# Processing Record 49 of Set 10 | lindenhurst
# Processing Record 50 of Set 10 | sayyan
# Processing Record 1 of Set 11 | aksarka
# Processing Record 2 of Set 11 | sechura
# Processing Record 3 of Set 11 | rincon
# Processing Record 4 of Set 11 | chabahar
# Processing Record 5 of Set 11 | sinnamary
# Processing Record 6 of Set 11 | delta
# Processing Record 7 of Set 11 | kudahuvadhoo
# Processing Record 8 of Set 11 | axim
# Processing Record 9 of Set 11 | ferme-neuve
# Processing Record 10 of Set 11 | safranbolu
# Processing Record 11 of Set 11 | shaowu
# Processing Record 12 of Set 11 | aasiaat
# Processing Record 13 of Set 11 | havre-saint-pierre
# Processing Record 14 of Set 11 | presidencia roque saenz pena
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | sapele
# Processing Record 17 of Set 11 | saint-marc
# Processing Record 18 of Set 11 | belaya kholunitsa
# Processing Record 19 of Set 11 | bengkulu
# Processing Record 20 of Set 11 | pokrovsk
# Processing Record 21 of Set 11 | colares
# Processing Record 22 of Set 11 | san patricio
# Processing Record 23 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | flin flon
# Processing Record 25 of Set 11 | havoysund
# Processing Record 26 of Set 11 | katima mulilo
# Processing Record 27 of Set 11 | cap-aux-meules
# Processing Record 28 of Set 11 | jardim
# Processing Record 29 of Set 11 | mantua
# Processing Record 30 of Set 11 | anapolis
# Processing Record 31 of Set 11 | port macquarie
# Processing Record 32 of Set 11 | manggar
# Processing Record 33 of Set 11 | nome
# Processing Record 34 of Set 11 | tanete
# Processing Record 35 of Set 11 | malyye derbety
# Processing Record 36 of Set 11 | jiangyou
# Processing Record 37 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 11 | inhambane
# Processing Record 39 of Set 11 | comodoro rivadavia
# Processing Record 40 of Set 11 | rio gallegos
# Processing Record 41 of Set 11 | bradford
# Processing Record 42 of Set 11 | santa maria
# Processing Record 43 of Set 11 | fort dodge
# Processing Record 44 of Set 11 | bulawayo
# Processing Record 45 of Set 11 | tigil
# Processing Record 46 of Set 11 | high level
# Processing Record 47 of Set 11 | bandarbeyla
# Processing Record 48 of Set 11 | andenes
# Processing Record 49 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 50 of Set 11 | pudozh
# Processing Record 1 of Set 12 | muravlenko
# Processing Record 2 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 12 | tari
# Processing Record 4 of Set 12 | olkhovka
# Processing Record 5 of Set 12 | sungairaya
# Processing Record 6 of Set 12 | pacific grove
# Processing Record 7 of Set 12 | yingcheng
# Processing Record 8 of Set 12 | vanavara
# Processing Record 9 of Set 12 | poltava
# Processing Record 10 of Set 12 | strezhevoy
# Processing Record 11 of Set 12 | abu dhabi
# Processing Record 12 of Set 12 | jhol
# Processing Record 13 of Set 12 | langham
# Processing Record 14 of Set 12 | shuya
# Processing Record 15 of Set 12 | yarada
# Processing Record 16 of Set 12 | along
# Processing Record 17 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 19 of Set 12 | lata
# Processing Record 20 of Set 12 | palmer
# Processing Record 21 of Set 12 | matara
# Processing Record 22 of Set 12 | bria
# Processing Record 23 of Set 12 | ahuimanu
# Processing Record 24 of Set 12 | tamandare
# Processing Record 25 of Set 12 | sangar
# Processing Record 26 of Set 12 | kotido
# Processing Record 27 of Set 12 | porto santo
# Processing Record 28 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 12 | maragogi
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | gamba
# Processing Record 32 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 12 | mikumi
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | ouadda
# Processing Record 36 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 12 | suez
# Processing Record 38 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 12 | marzuq
# Processing Record 40 of Set 12 | gewane
# Processing Record 41 of Set 12 | camacupa
# Processing Record 42 of Set 12 | karratha
# Processing Record 43 of Set 12 | tuni
# Processing Record 44 of Set 12 | sterling
# Processing Record 45 of Set 12 | iranshahr
# Processing Record 46 of Set 12 | soyo
# Processing Record 47 of Set 12 | atar
# Processing Record 48 of Set 12 | ostrovnoy
# Processing Record 49 of Set 12 | tianpeng
# Processing Record 50 of Set 12 | waddan
# Processing Record 1 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 13 | mgandu
# Processing Record 3 of Set 13 | kirakira
# Processing Record 4 of Set 13 | viesca
# Processing Record 5 of Set 13 | klyuchi
# Processing Record 6 of Set 13 | pitsunda
# Processing Record 7 of Set 13 | kyaikto
# Processing Record 8 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 13 | ponca city
# Processing Record 10 of Set 13 | carballo
# Processing Record 11 of Set 13 | alice springs
# Processing Record 12 of Set 13 | aklavik
# Processing Record 13 of Set 13 | tual
# Processing Record 14 of Set 13 | uruzgan
# Processing Record 15 of Set 13 | gravdal
# Processing Record 16 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 17 of Set 13 | tambopata
# Processing Record 18 of Set 13 | puga
# Processing Record 19 of Set 13 | valley city
# Processing Record 20 of Set 13 | sirjan
# Processing Record 21 of Set 13 | toppenish
# Processing Record 22 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 13 | faya
# Processing Record 24 of Set 13 | karaidel
# Processing Record 25 of Set 13 | bilma
# Processing Record 26 of Set 13 | vila velha
# Processing Record 27 of Set 13 | miyako
# Processing Record 28 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 13 | potsdam
# Processing Record 30 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 13 | tukrah
# Processing Record 32 of Set 13 | techiman
# Processing Record 33 of Set 13 | progreso
# Processing Record 34 of Set 13 | sarandi
# Processing Record 35 of Set 13 | verkhnevilyuysk
# Processing Record 36 of Set 13 | burdur
# Processing Record 37 of Set 13 | plettenberg bay
# Processing Record 38 of Set 13 | tateyama
# Processing Record 39 of Set 13 | tulun
# Processing Record 40 of Set 13 | smolenka
# Processing Record 41 of Set 13 | banjar
# Processing Record 42 of Set 13 | kailua
# Processing Record 43 of Set 13 | suluq
# Processing Record 44 of Set 13 | chunskiy
# Processing Record 45 of Set 13 | valparaiso
# Processing Record 46 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 47 of Set 13 | mezen
# Processing Record 48 of Set 13 | sakaiminato
# Processing Record 49 of Set 13 | la ronge
# Processing Record 50 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 14 | noyabrsk
# Processing Record 2 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 14 | batagay
# Processing Record 4 of Set 14 | vangaindrano
# Processing Record 5 of Set 14 | arkadak
# Processing Record 6 of Set 14 | kanda
# Processing Record 7 of Set 14 | atambua
# Processing Record 8 of Set 14 | gerede
# Processing Record 9 of Set 14 | trapani
# Processing Record 10 of Set 14 | kyren
# Processing Record 11 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 14 | burica
# City not found. Skipping...
# Processing Record 13 of Set 14 | luba
# Processing Record 14 of Set 14 | sorong
# Processing Record 15 of Set 14 | vallenar
# Processing Record 16 of Set 14 | reinosa
# Processing Record 17 of Set 14 | semnan
# Processing Record 18 of Set 14 | sakakah
# Processing Record 19 of Set 14 | mont-de-marsan
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | sinnar
# Processing Record 22 of Set 14 | shingu
# Processing Record 23 of Set 14 | ternate
# Processing Record 24 of Set 14 | dalby
# Processing Record 25 of Set 14 | makarov
# Processing Record 26 of Set 14 | ngorongoro
# Processing Record 27 of Set 14 | puerto baquerizo moreno
# Processing Record 28 of Set 14 | middelburg
# Processing Record 29 of Set 14 | aleksandrov gay
# Processing Record 30 of Set 14 | togur
# Processing Record 31 of Set 14 | brownsville
# Processing Record 32 of Set 14 | ettlingen
# Processing Record 33 of Set 14 | malvern
# Processing Record 34 of Set 14 | marrakesh
# Processing Record 35 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 14 | richards bay
# Processing Record 37 of Set 14 | labuhan
# Processing Record 38 of Set 14 | samandag
# Processing Record 39 of Set 14 | lamu
# Processing Record 40 of Set 14 | calabozo
# Processing Record 41 of Set 14 | kodinsk
# Processing Record 42 of Set 14 | umm kaddadah
# Processing Record 43 of Set 14 | presov
# Processing Record 44 of Set 14 | parabel
# Processing Record 45 of Set 14 | schenectady
# Processing Record 46 of Set 14 | hailar
# Processing Record 47 of Set 14 | mujiayingzi
# Processing Record 48 of Set 14 | kanniyakumari
# Processing Record 49 of Set 14 | mana
# Processing Record 50 of Set 14 | myanaung
# Processing Record 1 of Set 15 | bathsheba
# Processing Record 2 of Set 15 | fort nelson
# Processing Record 3 of Set 15 | bamberg
# Processing Record 4 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 15 | borovichi
# Processing Record 6 of Set 15 | inta
# Processing Record 7 of Set 15 | tahta
# Processing Record 8 of Set 15 | kiunga
# Processing Record 9 of Set 15 | purranque
# Processing Record 10 of Set 15 | fortuna
# Processing Record 11 of Set 15 | la rioja
# Processing Record 12 of Set 15 | kachug
# Processing Record 13 of Set 15 | kambove
# Processing Record 14 of Set 15 | santa engracia
# Processing Record 15 of Set 15 | ekibastuz
# Processing Record 16 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 17 of Set 15 | mount gambier
# Processing Record 18 of Set 15 | hinesburg
# Processing Record 19 of Set 15 | skibotn
# Processing Record 20 of Set 15 | okhotsk
# Processing Record 21 of Set 15 | amga
# Processing Record 22 of Set 15 | turayf
# Processing Record 23 of Set 15 | benoni
# Processing Record 24 of Set 15 | xinmin
# Processing Record 25 of Set 15 | killybegs
# Processing Record 26 of Set 15 | williston
# Processing Record 27 of Set 15 | voh
# Processing Record 28 of Set 15 | fuyu
# Processing Record 29 of Set 15 | khani
# Processing Record 30 of Set 15 | baillif
# Processing Record 31 of Set 15 | tarragona
# Processing Record 32 of Set 15 | chipinge
# Processing Record 33 of Set 15 | ketchikan
# Processing Record 34 of Set 15 | denau
# City not found. Skipping...
# Processing Record 35 of Set 15 | dufftown
# Processing Record 36 of Set 15 | launceston
# Processing Record 37 of Set 15 | prague
# Processing Record 38 of Set 15 | phrai bung
# City not found. Skipping...
# Processing Record 39 of Set 15 | vetlanda
# Processing Record 40 of Set 15 | redmond
# Processing Record 41 of Set 15 | majene
# Processing Record 42 of Set 15 | impfondo
# Processing Record 43 of Set 15 | kieta
# Processing Record 44 of Set 15 | hanzhong
# Processing Record 45 of Set 15 | shar
# Processing Record 46 of Set 15 | santa paula
# Processing Record 47 of Set 15 | adrar
# Processing Record 48 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 15 | dagua
# Processing Record 50 of Set 15 | nanortalik
# Processing Record 1 of Set 16 | nuuk
# Processing Record 2 of Set 16 | uvat
# Processing Record 3 of Set 16 | karatau
# Processing Record 4 of Set 16 | aktash
# Processing Record 5 of Set 16 | ferkessedougou
# Processing Record 6 of Set 16 | anahuac
# Processing Record 7 of Set 16 | tiarei
# Processing Record 8 of Set 16 | oranjestad
# Processing Record 9 of Set 16 | berlevag
# Processing Record 10 of Set 16 | gayeri
# Processing Record 11 of Set 16 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 16 | codajas
# Processing Record 13 of Set 16 | tessalit
# Processing Record 14 of Set 16 | merauke
# Processing Record 15 of Set 16 | erenhot
# Processing Record 16 of Set 16 | san matias
# Processing Record 17 of Set 16 | pultusk
# Processing Record 18 of Set 16 | llanes
# Processing Record 19 of Set 16 | pangai
# Processing Record 20 of Set 16 | mwinilunga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Mayo  38.8876  -76.5119     38.55        39           0
# 1           Torbay  47.6666  -52.7314     16.75        81         100
# 2          Kavieng  -2.5744  150.7967     81.16        77          82
# 3    Srednekolymsk  67.4500  153.6833    -36.83       100          58
# 4        Thinadhoo   0.5333   72.9333     82.62        69          75
# ..             ...      ...       ...       ...       ...         ...
# 692     San Matias -16.3667  -58.4000     83.50        74         100
# 693        Pultusk  52.7025   21.0828     42.06        85         100
# 694         Llanes  43.4198   -4.7549     51.89        70          71
# 695         Pangai -19.8000 -174.3500     79.16        79         100
# 696     Mwinilunga -11.7358   24.4293     62.76        97          98
#
#      Wind Speed Country                 Date Current Description
# 0          7.00      US  2022-02-06 18:43:01           clear sky
# 1         17.27      CA  2022-02-06 18:44:52          light snow
# 2          3.47      PG  2022-02-06 18:44:52       broken clouds
# 3          1.28      RU  2022-02-06 18:44:53       broken clouds
# 4         11.05      MV  2022-02-06 18:44:53       broken clouds
# ..          ...     ...                  ...                 ...
# 692        7.63      BO  2022-02-06 19:06:10     overcast clouds
# 693       20.49      PL  2022-02-06 19:06:10          light rain
# 694        8.63      ES  2022-02-06 19:06:10       broken clouds
# 695       23.96      TO  2022-02-06 19:06:11          light rain
# 696        3.47      ZM  2022-02-06 19:06:11          light rain
#
# [697 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
